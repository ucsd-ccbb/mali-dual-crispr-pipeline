# %% [markdown]
# # Dual CRISPR Screen Analysis
# # Step 3: Construct Counting
# Amanda Birmingham, CCBB, UCSD (abirmingham@ucsd.edu)
#
# ## Instructions
#
# To run this notebook reproducibly, follow these steps:
# 1. Click **Kernel** > **Restart & Clear Output**
# 2. When prompted, click the red **Restart & clear all outputs** button
# 3. Fill in the values for your analysis for each of the variables in the [Input Parameters](#Input-Parameters) section
# 4. Click **Cell** > **Run All**
#
# ## Input Parameters

# %%
g_timestamp = ''
g_num_processors = 3
g_filtered_fastqs_dir = ('/Users/Birmingham/Work/Repositories/ccbb_tickets_2017/mali-dual-crispr-pipeline/src/python/'
    'test_files/known_goods/filtered_fastq_20160706_HeLa_A549_CV4')
g_count_alg_name = '19mer_1mm_py'
g_constructs_fp = ('/Users/Birmingham/Work/Repositories/ccbb_tickets_2017/mali-dual-crispr-pipeline/src/python/'
    'test_files/known_goods/CV4_2spacers_w_probe_names.txt')
# Provide the zero-based indexes of the 7 columns for the following values, in the order given here:
# Construct ID (probe pair id), e.g. FGFR3_chr4_1795735__SMAD4_chr18_48586241
# Gene A name (target A name), e.g. FGFR3
# Probe A name, e.g. FGFR3_chr4_1795735
# Probe A sequence, e.g. GACGCGCTGCTCCGTCCCCA
# Gene B name (target B name), e.g. SMAD4
# Probe B name, e.g. SMAD4_chr18_48586241
# Probe B sequence, e.g. AATGCAAGCTCATTGTGAAC
g_col_indices_str = "1,3,6,7,8,11,12"
g_len_of_seq_to_match = 19
g_num_allowed_mismatches = 1
g_fastq_counts_dir = ('/Users/Birmingham/Work/Repositories/ccbb_tickets_2017/mali-dual-crispr-pipeline/src/python/'
    'test_files/test_outputs/notebook3_20160706_HeLa_A549_CV4')
g_fastq_counts_run_prefix = '20160706_HeLa_A549_CV4_placeholder'
g_code_location = '/Users/Birmingham/Work/Repositories/ccbb_tickets_2017/mali-dual-crispr-pipeline/src/python/'

# %% [markdown]
# ## Automated Set-Up

# %%
import inspect
import sys
sys.path.append(g_code_location)

import ccbbucsd.utilities.analysis_run_prefixes as ns_runs
import ccbbucsd.utilities.files_and_paths as ns_files
import ccbbucsd.utilities.notebook_logging as ns_logs


def describe_var_list(input_var_name_list):
    description_list =  ["{0}: {1}\n".format(name, eval(name)) for name in input_var_name_list]
    return "".join(description_list)


ns_logs.set_stdout_info_logger()

# %%
g_timestamp = ns_runs.check_or_set(g_timestamp, ns_runs.get_timestamp())
g_fastq_counts_dir = ns_runs.check_or_set(g_fastq_counts_dir, g_filtered_fastqs_dir)
g_fastq_counts_run_prefix = ns_runs.check_or_set(g_fastq_counts_run_prefix, 
                                        ns_runs.get_run_prefix(None, g_count_alg_name, g_timestamp))
g_col_indices = ns_runs.get_ints_from_comma_sep_string(g_col_indices_str)
print(describe_var_list(['g_timestamp','g_fastq_counts_dir', 'g_fastq_counts_run_prefix', 'g_col_indices']))
ns_files.verify_or_make_dir(g_fastq_counts_dir)
# Out:
# g_timestamp: 20170311141026
# g_fastq_counts_dir: /Users/Birmingham/Work/Repositories/ccbb_tickets_2017/mali-dual-crispr-pipeline/src/python/test_files/test_outputs/notebook3_20160706_HeLa_A549_CV4
# g_fastq_counts_run_prefix: 20160706_HeLa_A549_CV4_placeholder
# g_col_indices: [1, 3, 6, 7, 8, 11, 12]

# %% [markdown]
# ## Construct Counting Functions

# %%
import ccbbucsd.malicrispr.count_filterer as ns_filter
print(inspect.getsource(ns_filter.get_filtered_file_suffix))
# Out:
# def get_filtered_file_suffix():
#     return "_len_filtered.fastq"

# %%
import ccbbucsd.malicrispr.construct_file_extracter as ns_extracter
print(inspect.getsource(ns_extracter))
# Out:
# # third-party libraries
# import pandas
#
# # ccbb libraries
# from ccbbucsd.utilities.bio_seq_utilities import trim_seq
#
# __author__ = "Amanda Birmingham"
# __maintainer__ = "Amanda Birmingham"
# __email__ = "abirmingham@ucsd.edu"
# __status__ = "prototype"
#
# _CONSTRUCT_ID = "construct_id"
# _PROBE_A_SEQ = "probe_a_seq"
# _PROBE_B_SEQ = "probe_b_seq"
# _PROBE_A_NAME = "probe_a_id"
# _PROBE_B_NAME = "probe_b_id"
# _TARGET_A_NAME = "target_a_id"
# _TARGET_B_NAME = "target_b_id"
# _TARGET_PAIR_ID = "target_pair_id"
# _PROBE_PAIR_ID = "probe_pair_id"
# _HEADER_DIVIDER = "_"
#
#
# def get_header_divider():
#     return _HEADER_DIVIDER
#
#
# def get_construct_header():
#     return _CONSTRUCT_ID
#
#
# def get_probe_id_header(probe_letter):
#     return _PROBE_A_NAME if _is_letter_a(probe_letter) else _PROBE_B_NAME
#
#
# def get_probe_seq_header(probe_letter):
#     return _PROBE_A_SEQ if _is_letter_a(probe_letter) else _PROBE_B_SEQ
#
#
# def get_target_id_header(target_letter):
#     return _TARGET_A_NAME if _is_letter_a(target_letter) else _TARGET_B_NAME
#
#
# def get_target_pair_id_header():
#     return _TARGET_PAIR_ID
#
#
# def get_probe_pair_id_header():
#     return _PROBE_PAIR_ID
#
#
# def compose_probe_pair_id_from_probe_ids(probe_a_id, probe_b_id):
#     divider = get_header_divider()
#     result = probe_a_id + divider + divider + probe_b_id
#     return result
#
#
# def compose_target_pair_id_from_target_ids(target_a_id, target_b_id):
#     return target_a_id + get_header_divider() + target_b_id
#
#
# def extract_construct_and_grna_info(constructs_fp, column_indices):
#     construct_table = _read_in_construct_table(constructs_fp, column_indices, rows_to_skip=1)
#     seq_name_sets = _extract_unique_sets_across_a_and_b(construct_table,
#         [_PROBE_A_NAME, _PROBE_A_SEQ], [_PROBE_B_NAME, _PROBE_B_SEQ])
#     probe_name_seq_pairs = _validate_and_format_probe_seq_pairs(seq_name_sets)
#     construct_names = construct_table[_CONSTRUCT_ID].unique().tolist()
#     return construct_names, probe_name_seq_pairs
#
#
# def trim_probes(probes_name_and_seq_list, retain_len):
#     result = []
#     for name_seq_tuple in probes_name_and_seq_list:
#         probe_name = name_seq_tuple[0]
#         full_seq = name_seq_tuple[1]
#         trimmed_seq = trim_seq(full_seq, retain_len, False)  # False = do not retain from 5p end but from 3p end
#         result.append((probe_name, trimmed_seq))
#     return result
#
#
# def _is_letter_a(letter):
#     if letter.upper() == "A":
#         result = True
#     elif letter.upper() == "B":
#         result = False
#     else:
#         raise ValueError("Input '{0}' is not recognized as A or B.".format(letter))
#
#     return result
#
#
# def _read_in_construct_table(constructs_fp, column_indices, rows_to_skip=1):
#     result = pandas.read_table(constructs_fp, skiprows=rows_to_skip, header=None)
#     result = _rename_columns(result, column_indices)
#     return result
#
#
# def _rename_columns(construct_table, column_indices):
#     new_names = [_CONSTRUCT_ID, _TARGET_A_NAME, _PROBE_A_NAME, _PROBE_A_SEQ,
#                  _TARGET_B_NAME, _PROBE_B_NAME, _PROBE_B_SEQ]
#     existing_names = list(construct_table.columns.values)
#
#     if len(column_indices) != len(new_names):
#         raise ValueError("Expected indices for {0} columns but received indices for {1}.".format(
#             len(new_names), len(column_indices)))
#
#     existing_to_new_names = {}
#     for curr_index in range(0, len(column_indices)):
#         curr_col_index = column_indices[curr_index]
#         curr_existing_name = existing_names[curr_col_index]
#         existing_to_new_names[curr_existing_name] = new_names[curr_index]
#
#     return construct_table.rename(columns=existing_to_new_names)
#
#
# def _extract_unique_sets_across_a_and_b(construct_table, a_col_headers_list, b_col_headers_list):
#     if len(a_col_headers_list) != len(b_col_headers_list):
#         raise ValueError("A and B column header lists are not equal in length.")
#
#     new_headers_list = ["temp_header_{0}".format(i) for i in range(0,len(a_col_headers_list))]
#
#     # get the set of input columns for each of the two targets, assigning each the same
#     # set of (generic) column headers so that they can easily be concatenated
#     set_for_a = _extract_renamed_subset_df(construct_table, a_col_headers_list, new_headers_list)
#     set_for_b = _extract_renamed_subset_df(construct_table, b_col_headers_list, new_headers_list)
#     combined_set = pandas.concat([set_for_a, set_for_b])
#
#     # extract only the unique sets
#     grouped_combined_set = combined_set.groupby(new_headers_list).groups
#     result = [x for x in grouped_combined_set]
#     return sorted(result)  # NB sort so that output order is predictable
#
#
# def _extract_renamed_subset_df(construct_table, col_headers_list, new_headers_list):
#     result = construct_table.loc[:, col_headers_list]
#     rename_dictionary = dict(zip(col_headers_list, new_headers_list))
#     result.rename(columns=rename_dictionary, inplace=True)
#     return result
#
#
# def _validate_and_format_probe_seq_pairs(probes_seq_and_name_list):
#     expected_num_pieces = 2
#     seqs_by_names = {}
#     names_by_seqs = {}
#     result = []
#
#     for curr_set in probes_seq_and_name_list:
#         if len(curr_set) != expected_num_pieces:
#             raise ValueError(
#                 "input '{0}' has {1} pieces instead of the expected {2}".format(
#                     curr_set, len(curr_set), expected_num_pieces
#                 ))
#         curr_seq = curr_set[1]
#         curr_name = curr_set[0]
#
#         if curr_seq in names_by_seqs:
#             raise ValueError(
#                 "sequence '{0}' associated with name '{1}' but was already associated with name '{2}'".format(
#                     curr_seq, curr_name, names_by_seqs[curr_seq]
#                 ))
#
#         if curr_name in seqs_by_names:
#             raise ValueError(
#                 "name '{0}' associated with sequence '{1}' but was already associated with sequence '{2}'".format(
#                     curr_name, curr_seq, seqs_by_names[curr_name]
#                 ))
#
#         names_by_seqs[curr_seq] = curr_name
#         seqs_by_names[curr_name] = curr_seq
#
#         result.append((curr_name, curr_seq.upper())) # upper-case all probe seqs
#     # next pair in
#
#     return result
#
#
# def _alphabetize_two_fields_in_row(input_df, header_of_col_to_be_first, header_of_col_to_be_second):
#     is_row_dealphabetized = input_df[header_of_col_to_be_first] >input_df[header_of_col_to_be_second] # boolean array
#
#     # for dealphabetized rows, get header_of_col_to_be_first's value
#     orig_first_col_vals_for_out_of_order_rows = input_df.loc[is_row_dealphabetized, header_of_col_to_be_first]
#
#     # replace header_of_col_to_be_first's value with header_of_col_to_be_second's value for dealphabetized rows
#     input_df.loc[is_row_dealphabetized, header_of_col_to_be_first] = input_df.loc[is_row_dealphabetized,
#                                                                                 header_of_col_to_be_second]
#     # replace header_of_col_to_be_second's value with header_of_col_to_be_first's original value for dealphabetized rows
#     input_df.loc[is_row_dealphabetized, header_of_col_to_be_second] = orig_first_col_vals_for_out_of_order_rows
#     return input_df

# %%
import ccbbucsd.malicrispr.grna_position_matcher as ns_matcher
print(inspect.getsource(ns_matcher))
# Out:
# # ccbb libraries
# from ccbbucsd.utilities.bio_seq_utilities import rev_comp_canonical_dna_seq
#
# __author__ = "Amanda Birmingham"
# __maintainer__ = "Amanda Birmingham"
# __email__ = "abirmingham@ucsd.edu"
# __status__ = "development"
#
#
# class GrnaPositionMatcher:
#     @staticmethod
#     def _generate_seqs_to_check(fw_whole_seq, rv_whole_seq):
#         rc_whole_rv_seq = rev_comp_canonical_dna_seq(rv_whole_seq)
#         return fw_whole_seq, rc_whole_rv_seq
#
#     def __init__(self, grna_names_and_seqs, expected_len, num_allowed_fw_mismatches, num_allowed_rv_mismatches):
#         self._grna_names_and_seqs = grna_names_and_seqs
#         self._num_allowed_fw_mismatches = num_allowed_fw_mismatches
#         self._num_allowed_rv_mismatches = num_allowed_rv_mismatches
#         self._seq_len = expected_len
#
#     @property
#     def num_allowed_fw_mismatches(self):
#         return self._num_allowed_fw_mismatches
#
#     @property
#     def num_allowed_rv_mismatches(self):
#         return self._num_allowed_rv_mismatches
#
#     def find_fw_and_rv_read_matches(self, fw_whole_seq, rv_whole_seq):
#         fw_construct_window, rc_rv_construct_window = self._generate_seqs_to_check(fw_whole_seq, rv_whole_seq)
#         return self._id_pair_matches(fw_construct_window, rc_rv_construct_window)
#
#     def _id_pair_matches(self, input1_seq, input2_seq):
#         input2_match_name = None
#         input1_match_name = self._id_sequence_match(self.num_allowed_fw_mismatches, input1_seq)
#         if input1_match_name is not None:
#             input2_match_name = self._id_sequence_match(self.num_allowed_rv_mismatches, input2_seq)
#
#         return input1_match_name, input2_match_name
#
#     def _id_sequence_match(self, num_allowed_mismatches, input_seq):
#         found_name = None
#
#         # check for perfect matches
#         for potential_name, potential_reference in self._grna_names_and_seqs:
#             if input_seq == potential_reference:
#                 found_name = potential_name
#                 break
#
#         # if no perfect matches found, check for mismatches
#         if found_name is None:
#             min_found_mismatches = num_allowed_mismatches + 1  # nothing checked yet so num mismatches is maximum
#             found_name = None
#             for potential_name, potential_reference in self._grna_names_and_seqs:
#
#                 # this way is not elegant, but it IS fast :) .... >3x faster than XOR approach
#                 num_mismatches = 0
#                 for x in range(0, self._seq_len):
#                     if input_seq[x] != potential_reference[x]:  # NB assumption that both are the same fixed length!
#                         num_mismatches += 1
#                         if num_mismatches > num_allowed_mismatches:
#                             break
#
#                 if num_mismatches < min_found_mismatches:
#                     min_found_mismatches = num_mismatches
#                     if num_mismatches <= num_allowed_mismatches:
#                         found_name = potential_name
#
#         return found_name

# %%
import ccbbucsd.malicrispr.construct_counter as ns_counter
print(inspect.getsource(ns_counter))
# Out:
# """This module counts almost-perfect matches of small sequences within forward and reverse fastq sequence pairs."""
#
# # standard libraries
# import csv
# import datetime
# import logging
#
# # ccbb libraries
# from ccbbucsd.utilities.basic_fastq import FastqHandler, paired_fastq_generator
#
# # project-specific libraries
# from ccbbucsd.malicrispr.construct_file_extracter import compose_probe_pair_id_from_probe_ids
#
# __author__ = "Amanda Birmingham"
# __maintainer__ = "Amanda Birmingham"
# __email__ = "abirmingham@ucsd.edu"
# __status__ = "development"
#
#
# def get_counts_file_suffix():
#     return "counts.txt"
#
#
# def get_construct_header():
#     return "construct_id"
#
#
# def get_counter_from_names(names_to_count):
#     return {x: 0 for x in names_to_count}
#
#
# def generate_construct_counts(grna_matcher, construct_names, output_fp, fw_fastq_fp, rv_fastq_fp):
#     counts_info_tuple = _match_and_count_constructs_from_files(grna_matcher, construct_names, fw_fastq_fp, rv_fastq_fp)
#     counts_by_construct = counts_info_tuple[0]
#     counts_by_type = counts_info_tuple[1]
#     _write_counts(counts_by_construct, counts_by_type, output_fp)
#
#
# def _match_and_count_constructs_from_files(grna_matcher, construct_names, fw_fastq_fp, rv_fastq_fp):
#     construct_counts = get_counter_from_names(construct_names)
#     fw_fastq_handler = FastqHandler(fw_fastq_fp)
#     rv_fastq_handler = FastqHandler(rv_fastq_fp)
#     return _match_and_count_constructs(grna_matcher, construct_counts, fw_fastq_handler, rv_fastq_handler)
#
#
# def _match_and_count_constructs(grna_matcher, construct_counts, fw_fastq_handler, rv_fastq_handler):
#     summary_counts = {"num_pairs": 0, "num_pairs_unrecognized": 0, "num_constructs_found": 0,
#                       "num_constructs_unrecognized": 0, "num_constructs_recognized": 0}
#
#     paired_fastq_seqs = paired_fastq_generator(fw_fastq_handler, rv_fastq_handler)
#     for curr_pair_seqs in paired_fastq_seqs:
#         summary_counts["num_pairs"] += 1
#         _report_progress(summary_counts["num_pairs"])
#
#         grna_name_A, grna_name_B = grna_matcher.find_fw_and_rv_read_matches(*curr_pair_seqs)
#         if grna_name_A is not None and grna_name_B is not None:
#             # TODO: Note assumption that probe pair id is construct name!
#             # True in Mali screens, but if that won't be universal, must refactor here.
#             construct_name = compose_probe_pair_id_from_probe_ids(grna_name_A, grna_name_B)
#             summary_counts["num_constructs_found"] += 1
#
#             if construct_name in construct_counts:
#                 summary_counts["num_constructs_recognized"] += 1
#                 construct_counts[construct_name] += 1
#             else:
#                 summary_counts["num_constructs_unrecognized"] += 1
#                 logging.debug("Unrecognized construct name: {0}".format(construct_name))
#         else:
#             summary_counts["num_pairs_unrecognized"] += 1
#             logging.debug("Unrecognized sequence: {0},{1}".format(*curr_pair_seqs))
#
#     return construct_counts, summary_counts
#
#
# def _report_progress(num_fastq_pairs):
#     if num_fastq_pairs % 100000 == 0:
#         logging.info("On fastq pair number {0} at {1}".format(num_fastq_pairs, datetime.datetime.now()))
#
#
# def _write_counts(counts_by_construct, counts_by_type, output_fp):
#     construct_names = list(counts_by_construct.keys())
#     construct_names.sort()
#
#     with open(output_fp, 'w') as file_handle:
#         summary_pieces = []
#         for curr_key, curr_value in counts_by_type.items():
#             summary_pieces.append("{0}:{1}".format(curr_key, curr_value))
#         summary_comment = ",".join(summary_pieces)
#         summary_comment = "# " + summary_comment
#         header = [get_construct_header(), "counts"]
#         writer = csv.writer(file_handle, delimiter="\t")
#
#         writer.writerow([summary_comment])
#         writer.writerow(header)
#         for curr_name in construct_names:
#             row = [curr_name, counts_by_construct[curr_name]]
#             writer.writerow(row)

# %%
def count_constructs_for_one_fastq_pair(curr_base, run_prefix, seq_len, num_allowed_mismatches, constructs_fp, 
                                        col_indices, output_dir, fw_fastq_fp, rv_fastq_fp):
    construct_names, grna_name_seq_pairs = ns_extracter.extract_construct_and_grna_info(constructs_fp, col_indices)
    trimmed_grna_name_seq_pairs = ns_extracter.trim_probes(grna_name_seq_pairs, seq_len)
    # Note: currently same value (num_allowed_mismatches) is being used for number of mismatches allowed in forward
    # read and number of mismatches allowed in reverse read, but this can be altered if desired
    grna_matcher = ns_matcher.GrnaPositionMatcher(trimmed_grna_name_seq_pairs, seq_len, num_allowed_mismatches, 
                                       num_allowed_mismatches)    
    output_fp = ns_files.build_multipart_fp(output_dir, [curr_base, run_prefix, ns_counter.get_counts_file_suffix()])
    ns_counter.generate_construct_counts(grna_matcher, construct_names, output_fp, fw_fastq_fp, rv_fastq_fp)

# %%
import ccbbucsd.utilities.parallel_process_fastqs as ns_parallel

g_parallel_results = ns_parallel.parallel_process_paired_reads(g_filtered_fastqs_dir, 
    ns_filter.get_filtered_file_suffix(), g_num_processors, count_constructs_for_one_fastq_pair, 
    [g_fastq_counts_run_prefix, g_len_of_seq_to_match, g_num_allowed_mismatches, g_constructs_fp, 
    g_col_indices, g_fastq_counts_dir], True)
# Out:
# Starting parallel processing at 2017-03-11 14:10:36.724929
# Starting A549-CV4-d21-1_S3_L001_001_trimmed53_len_filtered at 2017-03-11 14:10:36.742734
# Starting A549-CV4-d21-1_S3_L002_001_trimmed53_len_filtered at 2017-03-11 14:10:36.743135
# Starting A549-CV4-d21-2_S4_L001_001_trimmed53_len_filtered at 2017-03-11 14:10:36.744154
# On fastq pair number 100000 at 2017-03-11 14:11:05.335385
# On fastq pair number 100000 at 2017-03-11 14:11:05.349628
# On fastq pair number 100000 at 2017-03-11 14:11:05.603018
# On fastq pair number 200000 at 2017-03-11 14:11:34.642733
# On fastq pair number 200000 at 2017-03-11 14:11:34.855973
# On fastq pair number 200000 at 2017-03-11 14:11:35.271021
# On fastq pair number 300000 at 2017-03-11 14:12:09.062735
# On fastq pair number 300000 at 2017-03-11 14:12:09.455267
# On fastq pair number 300000 at 2017-03-11 14:12:09.716147
# On fastq pair number 400000 at 2017-03-11 14:12:37.772228
# On fastq pair number 400000 at 2017-03-11 14:12:39.153528
# On fastq pair number 400000 at 2017-03-11 14:12:39.573376
# On fastq pair number 500000 at 2017-03-11 14:13:10.491648
# On fastq pair number 500000 at 2017-03-11 14:13:12.665806
# On fastq pair number 500000 at 2017-03-11 14:13:13.349462
# On fastq pair number 600000 at 2017-03-11 14:13:37.878528
# On fastq pair number 600000 at 2017-03-11 14:13:40.442807
# On fastq pair number 600000 at 2017-03-11 14:13:40.654888
# On fastq pair number 700000 at 2017-03-11 14:14:07.208117
# On fastq pair number 700000 at 2017-03-11 14:14:10.565847
# On fastq pair number 700000 at 2017-03-11 14:14:10.787069
# On fastq pair number 800000 at 2017-03-11 14:14:39.818427
# On fastq pair number 800000 at 2017-03-11 14:14:43.545449
# On fastq pair number 800000 at 2017-03-11 14:14:43.583115
# On fastq pair number 900000 at 2017-03-11 14:15:06.388582
# On fastq pair number 900000 at 2017-03-11 14:15:12.184162
# On fastq pair number 900000 at 2017-03-11 14:15:12.509439
# On fastq pair number 1000000 at 2017-03-11 14:15:38.843546
# On fastq pair number 1000000 at 2017-03-11 14:15:43.764890
# On fastq pair number 1000000 at 2017-03-11 14:15:44.566537
# On fastq pair number 1100000 at 2017-03-11 14:16:11.270100
# On fastq pair number 1100000 at 2017-03-11 14:16:16.016826
# On fastq pair number 1100000 at 2017-03-11 14:16:16.935764
# On fastq pair number 1200000 at 2017-03-11 14:16:37.950618
# On fastq pair number 1200000 at 2017-03-11 14:16:42.515283
# On fastq pair number 1200000 at 2017-03-11 14:16:43.196515
# On fastq pair number 1300000 at 2017-03-11 14:17:04.452635
# On fastq pair number 1300000 at 2017-03-11 14:17:11.660265
# On fastq pair number 1300000 at 2017-03-11 14:17:12.716560
# On fastq pair number 1400000 at 2017-03-11 14:17:36.542984
# On fastq pair number 1400000 at 2017-03-11 14:17:42.115318
# On fastq pair number 1400000 at 2017-03-11 14:17:43.665738
# On fastq pair number 1500000 at 2017-03-11 14:18:03.792217
# On fastq pair number 1500000 at 2017-03-11 14:18:10.119356
# On fastq pair number 1500000 at 2017-03-11 14:18:11.817035
# On fastq pair number 1600000 at 2017-03-11 14:18:33.265225
# On fastq pair number 1600000 at 2017-03-11 14:18:40.049261
# On fastq pair number 1600000 at 2017-03-11 14:18:41.392731
# On fastq pair number 1700000 at 2017-03-11 14:18:59.562258
# On fastq pair number 1700000 at 2017-03-11 14:19:06.100001
# On fastq pair number 1700000 at 2017-03-11 14:19:07.224024
# On fastq pair number 1800000 at 2017-03-11 14:19:25.935767
# On fastq pair number 1800000 at 2017-03-11 14:19:33.103324
# On fastq pair number 1800000 at 2017-03-11 14:19:34.452106
# On fastq pair number 1900000 at 2017-03-11 14:19:58.525681
# On fastq pair number 1900000 at 2017-03-11 14:20:05.508634
# On fastq pair number 1900000 at 2017-03-11 14:20:07.040249
# On fastq pair number 2000000 at 2017-03-11 14:20:23.355251
# On fastq pair number 2000000 at 2017-03-11 14:20:31.598454
# On fastq pair number 2000000 at 2017-03-11 14:20:33.532066
# On fastq pair number 2100000 at 2017-03-11 14:20:50.519922
# On fastq pair number 2100000 at 2017-03-11 14:21:00.692250
# On fastq pair number 2100000 at 2017-03-11 14:21:04.189795
# On fastq pair number 2200000 at 2017-03-11 14:21:21.905031
# On fastq pair number 2200000 at 2017-03-11 14:21:31.690360
# On fastq pair number 2200000 at 2017-03-11 14:21:34.391971
# On fastq pair number 2300000 at 2017-03-11 14:21:47.876626
# On fastq pair number 2300000 at 2017-03-11 14:21:58.619911
# On fastq pair number 2300000 at 2017-03-11 14:22:00.702240
# On fastq pair number 2400000 at 2017-03-11 14:22:13.653764
# On fastq pair number 2400000 at 2017-03-11 14:22:25.327629
# On fastq pair number 2400000 at 2017-03-11 14:22:27.465847
# On fastq pair number 2500000 at 2017-03-11 14:22:44.185331
# On fastq pair number 2500000 at 2017-03-11 14:22:55.783102
# On fastq pair number 2500000 at 2017-03-11 14:22:57.547865
# On fastq pair number 2600000 at 2017-03-11 14:23:10.962625
# On fastq pair number 2600000 at 2017-03-11 14:23:22.833449
# On fastq pair number 2600000 at 2017-03-11 14:23:25.028012
# On fastq pair number 2700000 at 2017-03-11 14:23:38.947795
# On fastq pair number 2700000 at 2017-03-11 14:23:54.313151
# On fastq pair number 2700000 at 2017-03-11 14:23:57.747141
# On fastq pair number 2800000 at 2017-03-11 14:24:09.041874
# On fastq pair number 2800000 at 2017-03-11 14:24:21.779100
# On fastq pair number 2800000 at 2017-03-11 14:24:23.982995
# On fastq pair number 2900000 at 2017-03-11 14:24:34.371337
# On fastq pair number 2900000 at 2017-03-11 14:24:47.520104
# On fastq pair number 2900000 at 2017-03-11 14:24:49.518425
# On fastq pair number 3000000 at 2017-03-11 14:24:59.101047
# On fastq pair number 3000000 at 2017-03-11 14:25:17.633131
# On fastq pair number 3000000 at 2017-03-11 14:25:19.643701
# On fastq pair number 3100000 at 2017-03-11 14:25:28.644591
# On fastq pair number 3100000 at 2017-03-11 14:25:43.078532
# On fastq pair number 3100000 at 2017-03-11 14:25:45.026745
# On fastq pair number 3200000 at 2017-03-11 14:25:53.775701
# On fastq pair number 3200000 at 2017-03-11 14:26:08.138022
# On fastq pair number 3200000 at 2017-03-11 14:26:10.118210
# On fastq pair number 3300000 at 2017-03-11 14:26:19.703126
# On fastq pair number 3300000 at 2017-03-11 14:26:39.043623
# On fastq pair number 3300000 at 2017-03-11 14:26:41.295318
# On fastq pair number 3400000 at 2017-03-11 14:26:48.870855
# On fastq pair number 3400000 at 2017-03-11 14:27:04.502925
# On fastq pair number 3400000 at 2017-03-11 14:27:07.283907
# On fastq pair number 3500000 at 2017-03-11 14:27:16.680943
# On fastq pair number 3500000 at 2017-03-11 14:27:33.736144
# On fastq pair number 3500000 at 2017-03-11 14:27:37.822478
# On fastq pair number 3600000 at 2017-03-11 14:27:46.657109
# On fastq pair number 3600000 at 2017-03-11 14:28:04.633224
# On fastq pair number 3600000 at 2017-03-11 14:28:10.362280
# On fastq pair number 3700000 at 2017-03-11 14:28:16.091780
# On fastq pair number 3700000 at 2017-03-11 14:28:33.211241
# On fastq pair number 3700000 at 2017-03-11 14:28:37.225463
# On fastq pair number 3800000 at 2017-03-11 14:28:42.119714
# On fastq pair number 3800000 at 2017-03-11 14:29:03.422186
# On fastq pair number 3800000 at 2017-03-11 14:29:08.918838
# On fastq pair number 3900000 at 2017-03-11 14:29:13.476646
# On fastq pair number 3900000 at 2017-03-11 14:29:34.221678
# On fastq pair number 3900000 at 2017-03-11 14:29:38.664434
# On fastq pair number 4000000 at 2017-03-11 14:29:42.376210
# On fastq pair number 4000000 at 2017-03-11 14:30:01.346043
# On fastq pair number 4000000 at 2017-03-11 14:30:05.537901
# On fastq pair number 4100000 at 2017-03-11 14:30:09.338899
# On fastq pair number 4100000 at 2017-03-11 14:30:31.839067
# On fastq pair number 4100000 at 2017-03-11 14:30:36.713143
# On fastq pair number 4200000 at 2017-03-11 14:30:39.380558
# On fastq pair number 4200000 at 2017-03-11 14:30:57.380472
# On fastq pair number 4200000 at 2017-03-11 14:31:02.720975
# On fastq pair number 4300000 at 2017-03-11 14:31:05.382345
# On fastq pair number 4300000 at 2017-03-11 14:31:24.412104
# On fastq pair number 4300000 at 2017-03-11 14:31:30.587092
# On fastq pair number 4400000 at 2017-03-11 14:31:34.076735
# On fastq pair number 4400000 at 2017-03-11 14:31:55.616313
# On fastq pair number 4400000 at 2017-03-11 14:32:00.873952
# On fastq pair number 4500000 at 2017-03-11 14:32:02.556384
# On fastq pair number 4500000 at 2017-03-11 14:32:22.433448
# On fastq pair number 4500000 at 2017-03-11 14:32:28.613440
# On fastq pair number 4600000 at 2017-03-11 14:32:30.068071
# On fastq pair number 4600000 at 2017-03-11 14:32:53.178721
# On fastq pair number 4700000 at 2017-03-11 14:33:00.946342
# On fastq pair number 4600000 at 2017-03-11 14:33:01.120030
# On fastq pair number 4700000 at 2017-03-11 14:33:22.208089
# On fastq pair number 4800000 at 2017-03-11 14:33:28.206591
# On fastq pair number 4700000 at 2017-03-11 14:33:28.889722
# On fastq pair number 4800000 at 2017-03-11 14:33:50.446738
# On fastq pair number 4900000 at 2017-03-11 14:33:56.039814
# On fastq pair number 4800000 at 2017-03-11 14:33:57.405822
# On fastq pair number 4900000 at 2017-03-11 14:34:21.766162
# On fastq pair number 5000000 at 2017-03-11 14:34:26.800102
# On fastq pair number 4900000 at 2017-03-11 14:34:28.478604
# On fastq pair number 5000000 at 2017-03-11 14:34:50.201123
# On fastq pair number 5100000 at 2017-03-11 14:34:54.536413
# On fastq pair number 5000000 at 2017-03-11 14:34:57.046965
# On fastq pair number 5100000 at 2017-03-11 14:35:16.542350
# On fastq pair number 5200000 at 2017-03-11 14:35:20.913108
# On fastq pair number 5100000 at 2017-03-11 14:35:24.878312
# On fastq pair number 5200000 at 2017-03-11 14:35:46.483618
# On fastq pair number 5300000 at 2017-03-11 14:35:50.805588
# On fastq pair number 5200000 at 2017-03-11 14:35:53.205620
# On fastq pair number 5300000 at 2017-03-11 14:36:12.692605
# On fastq pair number 5400000 at 2017-03-11 14:36:16.908113
# On fastq pair number 5300000 at 2017-03-11 14:36:19.890544
# On fastq pair number 5400000 at 2017-03-11 14:36:42.041877
# On fastq pair number 5500000 at 2017-03-11 14:36:47.530241
# On fastq pair number 5400000 at 2017-03-11 14:36:53.056043
# On fastq pair number 5500000 at 2017-03-11 14:37:12.119051
# On fastq pair number 5600000 at 2017-03-11 14:37:15.051768
# On fastq pair number 5500000 at 2017-03-11 14:37:19.498751
# On fastq pair number 5600000 at 2017-03-11 14:37:39.151611
# On fastq pair number 5700000 at 2017-03-11 14:37:41.582404
# On fastq pair number 5600000 at 2017-03-11 14:37:47.478075
# On fastq pair number 5700000 at 2017-03-11 14:38:09.523547
# On fastq pair number 5800000 at 2017-03-11 14:38:11.550612
# On fastq pair number 5700000 at 2017-03-11 14:38:18.186250
# On fastq pair number 5800000 at 2017-03-11 14:38:36.218249
# On fastq pair number 5900000 at 2017-03-11 14:38:37.979037
# On fastq pair number 5800000 at 2017-03-11 14:38:44.382551
# On fastq pair number 5900000 at 2017-03-11 14:39:03.160623
# On fastq pair number 6000000 at 2017-03-11 14:39:10.684000
# On fastq pair number 5900000 at 2017-03-11 14:39:11.514972
# On fastq pair number 6000000 at 2017-03-11 14:39:36.989637
# On fastq pair number 6000000 at 2017-03-11 14:39:45.747048
# On fastq pair number 6100000 at 2017-03-11 14:39:57.804113
# On fastq pair number 6100000 at 2017-03-11 14:40:10.105410
# On fastq pair number 6100000 at 2017-03-11 14:40:14.050484
# On fastq pair number 6200000 at 2017-03-11 14:40:26.604636
# On fastq pair number 6200000 at 2017-03-11 14:40:36.478880
# On fastq pair number 6200000 at 2017-03-11 14:40:50.557433
# On fastq pair number 6300000 at 2017-03-11 14:41:03.942354
# On fastq pair number 6300000 at 2017-03-11 14:41:04.128347
# On fastq pair number 6300000 at 2017-03-11 14:41:23.008248
# On fastq pair number 6400000 at 2017-03-11 14:41:28.754609
# On fastq pair number 6400000 at 2017-03-11 14:41:38.310138
# On fastq pair number 6500000 at 2017-03-11 14:41:53.593309
# On fastq pair number 6400000 at 2017-03-11 14:41:59.422419
# On fastq pair number 6500000 at 2017-03-11 14:42:07.309694
# On fastq pair number 6600000 at 2017-03-11 14:42:25.087356
# On fastq pair number 6500000 at 2017-03-11 14:42:33.109013
# On fastq pair number 6600000 at 2017-03-11 14:42:41.484152
# On fastq pair number 6700000 at 2017-03-11 14:43:58.044886
# On fastq pair number 6600000 at 2017-03-11 14:44:20.856655
# On fastq pair number 6700000 at 2017-03-11 14:44:21.766592
# On fastq pair number 6800000 at 2017-03-11 14:44:35.326091
# On fastq pair number 6800000 at 2017-03-11 14:44:50.244626
# On fastq pair number 6700000 at 2017-03-11 14:44:51.630946
# On fastq pair number 6900000 at 2017-03-11 14:44:58.141623
# On fastq pair number 6900000 at 2017-03-11 14:45:17.952002
# On fastq pair number 6800000 at 2017-03-11 14:45:18.051469
# On fastq pair number 7000000 at 2017-03-11 14:45:24.578218
# On fastq pair number 7000000 at 2017-03-11 14:45:41.792321
# On fastq pair number 6900000 at 2017-03-11 14:45:44.244733
# On fastq pair number 7100000 at 2017-03-11 14:45:47.042510
# On fastq pair number 7100000 at 2017-03-11 14:46:05.120614
# On fastq pair number 7000000 at 2017-03-11 14:46:09.304777
# On fastq pair number 7200000 at 2017-03-11 14:46:10.735239
# On fastq pair number 7100000 at 2017-03-11 14:46:41.998202
# On fastq pair number 7200000 at 2017-03-11 14:46:43.266893
# On fastq pair number 7300000 at 2017-03-11 14:46:43.479806
# On fastq pair number 7300000 at 2017-03-11 14:47:09.386109
# On fastq pair number 7400000 at 2017-03-11 14:47:09.937554
# On fastq pair number 7200000 at 2017-03-11 14:47:14.109609
# On fastq pair number 7400000 at 2017-03-11 14:47:32.351066
# On fastq pair number 7500000 at 2017-03-11 14:47:33.652310
# On fastq pair number 7300000 at 2017-03-11 14:47:37.836270
# On fastq pair number 7500000 at 2017-03-11 14:47:56.125979
# On fastq pair number 7600000 at 2017-03-11 14:47:59.050887
# On fastq pair number 7400000 at 2017-03-11 14:48:04.414080
# On fastq pair number 7600000 at 2017-03-11 14:48:20.319641
# On fastq pair number 7700000 at 2017-03-11 14:48:22.361361
# On fastq pair number 7500000 at 2017-03-11 14:48:27.640778
# On fastq pair number 7700000 at 2017-03-11 14:48:44.013657
# On fastq pair number 7800000 at 2017-03-11 14:48:46.493625
# On fastq pair number 7600000 at 2017-03-11 14:48:51.658082
# On fastq pair number 7800000 at 2017-03-11 14:49:10.887850
# On fastq pair number 7900000 at 2017-03-11 14:49:17.180902
# On fastq pair number 7700000 at 2017-03-11 14:49:23.372411
# On fastq pair number 7900000 at 2017-03-11 14:49:40.100187
# On fastq pair number 8000000 at 2017-03-11 14:49:43.154062
# On fastq pair number 7800000 at 2017-03-11 14:49:49.433501
# On fastq pair number 8000000 at 2017-03-11 14:50:06.361632
# On fastq pair number 8100000 at 2017-03-11 14:50:08.062947
# On fastq pair number 7900000 at 2017-03-11 14:50:13.009704
# On fastq pair number 8100000 at 2017-03-11 14:50:30.036322
# On fastq pair number 8200000 at 2017-03-11 14:50:32.356030
# On fastq pair number 8000000 at 2017-03-11 14:50:38.674750
# On fastq pair number 8200000 at 2017-03-11 14:50:52.923710
# On fastq pair number 8300000 at 2017-03-11 14:50:54.827115
# On fastq pair number 8100000 at 2017-03-11 14:51:01.711804
# On fastq pair number 8300000 at 2017-03-11 14:51:13.885829
# On fastq pair number 8400000 at 2017-03-11 14:51:15.442977
# On fastq pair number 8200000 at 2017-03-11 14:51:23.646315
# On fastq pair number 8400000 at 2017-03-11 14:51:37.143250
# On fastq pair number 8500000 at 2017-03-11 14:51:39.487967
# On fastq pair number 8300000 at 2017-03-11 14:51:50.537519
# On fastq pair number 8500000 at 2017-03-11 14:52:00.532117
# On fastq pair number 8600000 at 2017-03-11 14:52:02.467691
# On fastq pair number 8400000 at 2017-03-11 14:52:10.888072
# On fastq pair number 8600000 at 2017-03-11 14:52:20.362828
# On fastq pair number 8700000 at 2017-03-11 14:52:22.490455
# On fastq pair number 8500000 at 2017-03-11 14:52:31.253277
# On fastq pair number 8700000 at 2017-03-11 14:52:40.986618
# On fastq pair number 8800000 at 2017-03-11 14:52:43.864481
# On fastq pair number 8600000 at 2017-03-11 14:52:53.590410
# On fastq pair number 8800000 at 2017-03-11 14:53:05.262621
# On fastq pair number 8900000 at 2017-03-11 14:53:07.793528
# On fastq pair number 8700000 at 2017-03-11 14:53:16.422132
# On fastq pair number 8900000 at 2017-03-11 14:53:25.362862
# On fastq pair number 9000000 at 2017-03-11 14:53:28.458371
# On fastq pair number 8800000 at 2017-03-11 14:53:36.945735
# On fastq pair number 9000000 at 2017-03-11 14:53:47.123180
# On fastq pair number 9100000 at 2017-03-11 14:53:51.572900
# On fastq pair number 8900000 at 2017-03-11 14:54:00.009740
# On fastq pair number 9100000 at 2017-03-11 14:54:09.507403
# On fastq pair number 9200000 at 2017-03-11 14:54:15.965581
# On fastq pair number 9000000 at 2017-03-11 14:54:26.448728
# On fastq pair number 9200000 at 2017-03-11 14:54:35.855447
# On fastq pair number 9300000 at 2017-03-11 14:54:42.939227
# On fastq pair number 9100000 at 2017-03-11 14:54:53.703485
# On fastq pair number 9300000 at 2017-03-11 14:55:05.149711
# On fastq pair number 9400000 at 2017-03-11 14:55:08.972026
# On fastq pair number 9200000 at 2017-03-11 14:55:20.731477
# On fastq pair number 9400000 at 2017-03-11 14:55:38.247935
# On fastq pair number 9500000 at 2017-03-11 14:55:40.506195
# On fastq pair number 9300000 at 2017-03-11 14:55:49.744707
# On fastq pair number 9600000 at 2017-03-11 14:56:06.158660
# On fastq pair number 9400000 at 2017-03-11 14:56:16.857649
# On fastq pair number 9500000 at 2017-03-11 14:56:17.037363
# On fastq pair number 9700000 at 2017-03-11 14:56:28.501648
# On fastq pair number 9500000 at 2017-03-11 14:56:46.611137
# On fastq pair number 9600000 at 2017-03-11 14:56:47.883175
# On fastq pair number 9800000 at 2017-03-11 14:56:55.128370
# On fastq pair number 9700000 at 2017-03-11 14:57:11.564293
# On fastq pair number 9900000 at 2017-03-11 14:57:16.391645
# On fastq pair number 9600000 at 2017-03-11 14:57:22.557572
# On fastq pair number 9800000 at 2017-03-11 14:57:33.556220
# On fastq pair number 10000000 at 2017-03-11 14:57:38.767488
# On fastq pair number 9700000 at 2017-03-11 14:57:47.707307
# On fastq pair number 9900000 at 2017-03-11 14:57:55.592428
# On fastq pair number 10100000 at 2017-03-11 14:58:04.935565
# On fastq pair number 9800000 at 2017-03-11 14:58:14.235713
# On fastq pair number 10000000 at 2017-03-11 14:58:22.907801
# On fastq pair number 10200000 at 2017-03-11 14:58:30.396803
# On fastq pair number 9900000 at 2017-03-11 14:58:38.234809
# On fastq pair number 10100000 at 2017-03-11 14:58:45.488251
# On fastq pair number 10300000 at 2017-03-11 14:58:54.869487
# On fastq pair number 10000000 at 2017-03-11 14:59:03.732363
# On fastq pair number 10200000 at 2017-03-11 14:59:11.396235
# On fastq pair number 10400000 at 2017-03-11 14:59:22.717461
# On fastq pair number 10100000 at 2017-03-11 14:59:33.292803
# On fastq pair number 10300000 at 2017-03-11 14:59:41.358285
# On fastq pair number 10500000 at 2017-03-11 14:59:50.849221
# On fastq pair number 10200000 at 2017-03-11 14:59:59.181410
# On fastq pair number 10400000 at 2017-03-11 15:00:07.432878
# On fastq pair number 10600000 at 2017-03-11 15:00:15.923421
# On fastq pair number 10300000 at 2017-03-11 15:00:24.355351
# On fastq pair number 10500000 at 2017-03-11 15:00:32.338975
# On fastq pair number 10700000 at 2017-03-11 15:00:43.764165
# On fastq pair number 10400000 at 2017-03-11 15:00:52.127572
# On fastq pair number 10600000 at 2017-03-11 15:01:00.907653
# On fastq pair number 10800000 at 2017-03-11 15:01:12.245590
# On fastq pair number 10500000 at 2017-03-11 15:01:21.461840
# On fastq pair number 10700000 at 2017-03-11 15:01:26.768128
# On fastq pair number 10900000 at 2017-03-11 15:01:38.773291
# On fastq pair number 10600000 at 2017-03-11 15:01:53.160125
# On fastq pair number 10800000 at 2017-03-11 15:02:00.735724
# On fastq pair number 11000000 at 2017-03-11 15:02:12.752975
# On fastq pair number 10700000 at 2017-03-11 15:02:24.331860
# On fastq pair number 10900000 at 2017-03-11 15:02:29.403550
# A549-CV4-d21-1_S3_L002_001_trimmed53_len_filtered elapsed time: 0:50:52
# Starting A549-CV4-d21-2_S4_L002_001_trimmed53_len_filtered at 2017-03-11 15:02:30.368009
# On fastq pair number 10800000 at 2017-03-11 15:02:50.722774
# On fastq pair number 11000000 at 2017-03-11 15:02:55.540083
# On fastq pair number 100000 at 2017-03-11 15:02:56.915370
# A549-CV4-d21-2_S4_L001_001_trimmed53_len_filtered elapsed time: 0:51:21
# Starting A549-CV4-d28-1_S5_L001_001_trimmed53_len_filtered at 2017-03-11 15:02:59.783759
# On fastq pair number 10900000 at 2017-03-11 15:03:22.999708
# On fastq pair number 200000 at 2017-03-11 15:03:27.810485
# On fastq pair number 100000 at 2017-03-11 15:03:31.144858
# On fastq pair number 11000000 at 2017-03-11 15:03:46.990955
# On fastq pair number 300000 at 2017-03-11 15:03:50.821638
# On fastq pair number 200000 at 2017-03-11 15:03:54.934011
# A549-CV4-d21-1_S3_L001_001_trimmed53_len_filtered elapsed time: 0:52:30
# Starting A549-CV4-d28-1_S5_L002_001_trimmed53_len_filtered at 2017-03-11 15:04:08.981034
# On fastq pair number 400000 at 2017-03-11 15:04:14.648888
# On fastq pair number 300000 at 2017-03-11 15:04:19.902412
# On fastq pair number 100000 at 2017-03-11 15:04:36.463906
# On fastq pair number 500000 at 2017-03-11 15:04:41.082906
# On fastq pair number 400000 at 2017-03-11 15:04:45.237908
# On fastq pair number 200000 at 2017-03-11 15:05:00.880358
# On fastq pair number 600000 at 2017-03-11 15:05:05.896663
# On fastq pair number 500000 at 2017-03-11 15:05:10.058989
# On fastq pair number 300000 at 2017-03-11 15:05:25.588083
# On fastq pair number 700000 at 2017-03-11 15:05:29.961000
# On fastq pair number 600000 at 2017-03-11 15:05:36.113479
# On fastq pair number 400000 at 2017-03-11 15:05:50.985479
# On fastq pair number 800000 at 2017-03-11 15:05:55.767168
# On fastq pair number 700000 at 2017-03-11 15:05:59.664723
# On fastq pair number 500000 at 2017-03-11 15:06:15.729010
# On fastq pair number 900000 at 2017-03-11 15:06:20.424958
# On fastq pair number 800000 at 2017-03-11 15:06:25.171892
# On fastq pair number 600000 at 2017-03-11 15:06:46.238936
# On fastq pair number 1000000 at 2017-03-11 15:06:49.497411
# On fastq pair number 900000 at 2017-03-11 15:06:54.515666
# On fastq pair number 700000 at 2017-03-11 15:07:08.119491
# On fastq pair number 1100000 at 2017-03-11 15:07:10.948646
# On fastq pair number 1000000 at 2017-03-11 15:07:15.937125
# On fastq pair number 800000 at 2017-03-11 15:07:30.258482
# On fastq pair number 1200000 at 2017-03-11 15:07:32.638017
# On fastq pair number 1100000 at 2017-03-11 15:07:37.367854
# On fastq pair number 900000 at 2017-03-11 15:07:56.871367
# On fastq pair number 1300000 at 2017-03-11 15:07:59.198541
# On fastq pair number 1200000 at 2017-03-11 15:08:04.131174
# On fastq pair number 1000000 at 2017-03-11 15:08:18.833828
# On fastq pair number 1400000 at 2017-03-11 15:08:20.769719
# On fastq pair number 1300000 at 2017-03-11 15:08:25.295990
# On fastq pair number 1100000 at 2017-03-11 15:08:39.757198
# On fastq pair number 1500000 at 2017-03-11 15:08:41.527028
# On fastq pair number 1400000 at 2017-03-11 15:08:45.936438
# On fastq pair number 1200000 at 2017-03-11 15:09:02.068524
# On fastq pair number 1600000 at 2017-03-11 15:09:03.481155
# On fastq pair number 1500000 at 2017-03-11 15:09:08.033402
# On fastq pair number 1300000 at 2017-03-11 15:09:24.168574
# On fastq pair number 1700000 at 2017-03-11 15:09:25.582867
# On fastq pair number 1600000 at 2017-03-11 15:09:32.658288
# On fastq pair number 1400000 at 2017-03-11 15:09:49.310458
# On fastq pair number 1800000 at 2017-03-11 15:09:50.081662
# On fastq pair number 1700000 at 2017-03-11 15:09:54.924020
# On fastq pair number 1500000 at 2017-03-11 15:10:10.771008
# On fastq pair number 1900000 at 2017-03-11 15:10:11.216655
# On fastq pair number 1800000 at 2017-03-11 15:10:16.634032
# On fastq pair number 1600000 at 2017-03-11 15:10:32.144434
# On fastq pair number 2000000 at 2017-03-11 15:10:32.575495
# On fastq pair number 1900000 at 2017-03-11 15:10:38.240372
# On fastq pair number 1700000 at 2017-03-11 15:10:53.152009
# On fastq pair number 2100000 at 2017-03-11 15:10:54.252008
# On fastq pair number 2000000 at 2017-03-11 15:11:00.062902
# On fastq pair number 1800000 at 2017-03-11 15:11:17.335254
# On fastq pair number 2200000 at 2017-03-11 15:11:18.535385
# On fastq pair number 2100000 at 2017-03-11 15:11:23.130409
# On fastq pair number 1900000 at 2017-03-11 15:11:38.900030
# On fastq pair number 2300000 at 2017-03-11 15:11:40.211277
# On fastq pair number 2200000 at 2017-03-11 15:11:45.522891
# On fastq pair number 2000000 at 2017-03-11 15:12:01.763524
# On fastq pair number 2400000 at 2017-03-11 15:12:02.680552
# On fastq pair number 2300000 at 2017-03-11 15:12:07.842875
# On fastq pair number 2100000 at 2017-03-11 15:12:28.542024
# On fastq pair number 2500000 at 2017-03-11 15:12:28.975276
# On fastq pair number 2400000 at 2017-03-11 15:12:34.204753
# On fastq pair number 2200000 at 2017-03-11 15:12:49.601740
# On fastq pair number 2600000 at 2017-03-11 15:12:50.261686
# On fastq pair number 2500000 at 2017-03-11 15:12:56.249122
# On fastq pair number 2300000 at 2017-03-11 15:13:13.257112
# On fastq pair number 2700000 at 2017-03-11 15:13:13.580767
# On fastq pair number 2600000 at 2017-03-11 15:13:19.087491
# On fastq pair number 2400000 at 2017-03-11 15:13:36.501191
# On fastq pair number 2800000 at 2017-03-11 15:13:36.684200
# On fastq pair number 2700000 at 2017-03-11 15:13:41.510195
# On fastq pair number 2900000 at 2017-03-11 15:14:00.734129
# On fastq pair number 2500000 at 2017-03-11 15:14:01.307606
# On fastq pair number 2800000 at 2017-03-11 15:14:06.234607
# On fastq pair number 3000000 at 2017-03-11 15:14:24.904220
# On fastq pair number 2600000 at 2017-03-11 15:14:26.526434
# On fastq pair number 2900000 at 2017-03-11 15:14:32.310350
# On fastq pair number 3100000 at 2017-03-11 15:14:48.525754
# On fastq pair number 2700000 at 2017-03-11 15:14:51.082892
# On fastq pair number 3000000 at 2017-03-11 15:14:55.743833
# On fastq pair number 3200000 at 2017-03-11 15:15:13.600502
# On fastq pair number 2800000 at 2017-03-11 15:15:18.062071
# On fastq pair number 3100000 at 2017-03-11 15:15:23.390116
# On fastq pair number 3300000 at 2017-03-11 15:15:37.765394
# On fastq pair number 2900000 at 2017-03-11 15:15:41.086900
# On fastq pair number 3200000 at 2017-03-11 15:15:45.417387
# On fastq pair number 3400000 at 2017-03-11 15:15:59.655237
# On fastq pair number 3000000 at 2017-03-11 15:16:04.009861
# On fastq pair number 3300000 at 2017-03-11 15:16:09.126216
# On fastq pair number 3500000 at 2017-03-11 15:16:22.253028
# On fastq pair number 3100000 at 2017-03-11 15:16:27.225815
# On fastq pair number 3400000 at 2017-03-11 15:16:32.072403
# On fastq pair number 3600000 at 2017-03-11 15:16:47.792545
# On fastq pair number 3200000 at 2017-03-11 15:16:53.756689
# On fastq pair number 3500000 at 2017-03-11 15:16:58.256565
# On fastq pair number 3700000 at 2017-03-11 15:17:10.008159
# On fastq pair number 3300000 at 2017-03-11 15:17:15.862979
# On fastq pair number 3600000 at 2017-03-11 15:17:19.987087
# On fastq pair number 3800000 at 2017-03-11 15:17:31.732170
# On fastq pair number 3400000 at 2017-03-11 15:17:37.733784
# On fastq pair number 3700000 at 2017-03-11 15:17:41.698123
# On fastq pair number 3900000 at 2017-03-11 15:17:53.268392
# On fastq pair number 3500000 at 2017-03-11 15:17:59.425964
# On fastq pair number 3800000 at 2017-03-11 15:18:03.379566
# On fastq pair number 4000000 at 2017-03-11 15:18:21.094528
# On fastq pair number 3600000 at 2017-03-11 15:18:26.685353
# On fastq pair number 3900000 at 2017-03-11 15:18:31.186802
# On fastq pair number 4100000 at 2017-03-11 15:18:43.330111
# On fastq pair number 3700000 at 2017-03-11 15:18:49.074070
# On fastq pair number 4000000 at 2017-03-11 15:18:52.714066
# On fastq pair number 4200000 at 2017-03-11 15:19:05.635615
# On fastq pair number 3800000 at 2017-03-11 15:19:12.526030
# On fastq pair number 4100000 at 2017-03-11 15:19:16.441687
# On fastq pair number 4300000 at 2017-03-11 15:19:28.581588
# On fastq pair number 3900000 at 2017-03-11 15:19:35.257393
# On fastq pair number 4200000 at 2017-03-11 15:19:38.792042
# On fastq pair number 4400000 at 2017-03-11 15:19:51.615516
# On fastq pair number 4000000 at 2017-03-11 15:19:59.925804
# On fastq pair number 4300000 at 2017-03-11 15:20:04.221536
# On fastq pair number 4500000 at 2017-03-11 15:20:17.487645
# On fastq pair number 4100000 at 2017-03-11 15:20:23.404343
# On fastq pair number 4400000 at 2017-03-11 15:20:26.305057
# On fastq pair number 4600000 at 2017-03-11 15:20:38.783531
# On fastq pair number 4200000 at 2017-03-11 15:20:44.371395
# On fastq pair number 4500000 at 2017-03-11 15:20:48.054803
# On fastq pair number 4700000 at 2017-03-11 15:21:02.174408
# On fastq pair number 4300000 at 2017-03-11 15:21:09.165953
# On fastq pair number 4600000 at 2017-03-11 15:21:14.742143
# On fastq pair number 4800000 at 2017-03-11 15:21:32.020633
# On fastq pair number 4400000 at 2017-03-11 15:21:37.923452
# On fastq pair number 4700000 at 2017-03-11 15:21:41.235751
# On fastq pair number 4900000 at 2017-03-11 15:21:56.326341
# On fastq pair number 4500000 at 2017-03-11 15:22:01.305355
# On fastq pair number 4800000 at 2017-03-11 15:22:04.446749
# On fastq pair number 5000000 at 2017-03-11 15:22:17.698751
# On fastq pair number 4600000 at 2017-03-11 15:22:22.866601
# On fastq pair number 4900000 at 2017-03-11 15:22:26.269837
# On fastq pair number 5100000 at 2017-03-11 15:22:39.562422
# On fastq pair number 4700000 at 2017-03-11 15:22:44.287531
# On fastq pair number 5000000 at 2017-03-11 15:22:47.746361
# On fastq pair number 5200000 at 2017-03-11 15:23:01.722524
# On fastq pair number 4800000 at 2017-03-11 15:23:06.719147
# On fastq pair number 5100000 at 2017-03-11 15:23:12.196427
# On fastq pair number 5300000 at 2017-03-11 15:23:29.743303
# On fastq pair number 4900000 at 2017-03-11 15:23:34.040101
# On fastq pair number 5200000 at 2017-03-11 15:23:37.832659
# On fastq pair number 5400000 at 2017-03-11 15:23:52.142036
# On fastq pair number 5000000 at 2017-03-11 15:23:56.223982
# On fastq pair number 5300000 at 2017-03-11 15:24:00.247153
# On fastq pair number 5500000 at 2017-03-11 15:24:13.661308
# On fastq pair number 5100000 at 2017-03-11 15:24:18.030477
# On fastq pair number 5400000 at 2017-03-11 15:24:22.652459
# On fastq pair number 5600000 at 2017-03-11 15:24:39.703062
# On fastq pair number 5200000 at 2017-03-11 15:24:44.384322
# On fastq pair number 5500000 at 2017-03-11 15:24:47.828352
# On fastq pair number 5700000 at 2017-03-11 15:25:01.563890
# On fastq pair number 5300000 at 2017-03-11 15:25:07.361539
# On fastq pair number 5600000 at 2017-03-11 15:25:10.671660
# On fastq pair number 5800000 at 2017-03-11 15:25:24.815005
# On fastq pair number 5400000 at 2017-03-11 15:25:32.852004
# On fastq pair number 5700000 at 2017-03-11 15:25:35.393422
# On fastq pair number 5900000 at 2017-03-11 15:25:48.340553
# On fastq pair number 5500000 at 2017-03-11 15:25:55.798240
# On fastq pair number 5800000 at 2017-03-11 15:25:59.216980
# On fastq pair number 6000000 at 2017-03-11 15:26:17.512017
# On fastq pair number 5600000 at 2017-03-11 15:26:23.584624
# On fastq pair number 5900000 at 2017-03-11 15:26:26.315127
# On fastq pair number 6100000 at 2017-03-11 15:26:40.630736
# On fastq pair number 5700000 at 2017-03-11 15:26:47.636578
# On fastq pair number 6000000 at 2017-03-11 15:26:49.859398
# On fastq pair number 6200000 at 2017-03-11 15:27:05.682718
# On fastq pair number 5800000 at 2017-03-11 15:27:12.315491
# On fastq pair number 6100000 at 2017-03-11 15:27:13.960596
# On fastq pair number 6300000 at 2017-03-11 15:27:30.214852
# On fastq pair number 5900000 at 2017-03-11 15:27:37.191097
# On fastq pair number 6200000 at 2017-03-11 15:27:38.490350
# On fastq pair number 6400000 at 2017-03-11 15:27:55.069327
# On fastq pair number 6000000 at 2017-03-11 15:28:02.592526
# On fastq pair number 6300000 at 2017-03-11 15:28:03.837445
# On fastq pair number 6500000 at 2017-03-11 15:28:20.751457
# On fastq pair number 6100000 at 2017-03-11 15:28:26.960055
# On fastq pair number 6400000 at 2017-03-11 15:28:27.658823
# On fastq pair number 6600000 at 2017-03-11 15:28:45.774255
# On fastq pair number 6200000 at 2017-03-11 15:28:50.507013
# On fastq pair number 6500000 at 2017-03-11 15:28:50.519982
# On fastq pair number 6700000 at 2017-03-11 15:29:13.154366
# On fastq pair number 6600000 at 2017-03-11 15:29:17.798182
# On fastq pair number 6300000 at 2017-03-11 15:29:18.041164
# On fastq pair number 6800000 at 2017-03-11 15:29:37.863234
# On fastq pair number 6700000 at 2017-03-11 15:29:41.116448
# On fastq pair number 6400000 at 2017-03-11 15:29:41.422619
# On fastq pair number 6900000 at 2017-03-11 15:30:00.371471
# On fastq pair number 6800000 at 2017-03-11 15:30:03.848448
# On fastq pair number 6500000 at 2017-03-11 15:30:04.661875
# On fastq pair number 7000000 at 2017-03-11 15:30:21.083004
# On fastq pair number 6900000 at 2017-03-11 15:30:24.539622
# On fastq pair number 6600000 at 2017-03-11 15:30:25.557023
# On fastq pair number 7100000 at 2017-03-11 15:30:43.480715
# On fastq pair number 7000000 at 2017-03-11 15:30:47.891244
# On fastq pair number 6700000 at 2017-03-11 15:30:49.472698
# On fastq pair number 7200000 at 2017-03-11 15:31:05.778279
# On fastq pair number 7100000 at 2017-03-11 15:31:08.423715
# On fastq pair number 6800000 at 2017-03-11 15:31:10.278301
# On fastq pair number 7300000 at 2017-03-11 15:31:26.083593
# On fastq pair number 7200000 at 2017-03-11 15:31:29.452136
# On fastq pair number 6900000 at 2017-03-11 15:31:30.441631
# On fastq pair number 7400000 at 2017-03-11 15:31:46.572935
# On fastq pair number 7000000 at 2017-03-11 15:31:50.381567
# On fastq pair number 7300000 at 2017-03-11 15:31:58.290879
# On fastq pair number 7500000 at 2017-03-11 15:32:07.759321
# On fastq pair number 7100000 at 2017-03-11 15:32:12.103160
# On fastq pair number 7600000 at 2017-03-11 15:32:34.870411
# On fastq pair number 7200000 at 2017-03-11 15:32:38.526598
# On fastq pair number 7400000 at 2017-03-11 15:32:39.708755
# On fastq pair number 7700000 at 2017-03-11 15:32:56.788053
# On fastq pair number 7300000 at 2017-03-11 15:33:03.646236
# On fastq pair number 7500000 at 2017-03-11 15:33:04.291682
# On fastq pair number 7800000 at 2017-03-11 15:33:28.259367
# On fastq pair number 7400000 at 2017-03-11 15:33:40.435414
# On fastq pair number 7600000 at 2017-03-11 15:33:52.450394
# On fastq pair number 7900000 at 2017-03-11 15:33:59.634659
# On fastq pair number 7500000 at 2017-03-11 15:34:06.853253
# On fastq pair number 8000000 at 2017-03-11 15:34:24.869850
# On fastq pair number 7700000 at 2017-03-11 15:34:31.107946
# On fastq pair number 7600000 at 2017-03-11 15:34:36.012977
# On fastq pair number 8100000 at 2017-03-11 15:34:51.604784
# On fastq pair number 7800000 at 2017-03-11 15:35:04.469940
# On fastq pair number 7700000 at 2017-03-11 15:35:05.082154
# On fastq pair number 8200000 at 2017-03-11 15:35:18.095593
# On fastq pair number 7800000 at 2017-03-11 15:35:28.706117
# On fastq pair number 7900000 at 2017-03-11 15:35:33.817103
# On fastq pair number 8300000 at 2017-03-11 15:35:40.472348
# On fastq pair number 7900000 at 2017-03-11 15:35:52.545821
# On fastq pair number 8000000 at 2017-03-11 15:36:01.265126
# On fastq pair number 8400000 at 2017-03-11 15:36:03.887147
# On fastq pair number 8000000 at 2017-03-11 15:36:16.992602
# On fastq pair number 8500000 at 2017-03-11 15:36:25.442785
# On fastq pair number 8100000 at 2017-03-11 15:36:27.040888
# On fastq pair number 8100000 at 2017-03-11 15:36:46.244950
# On fastq pair number 8600000 at 2017-03-11 15:36:54.485519
# On fastq pair number 8200000 at 2017-03-11 15:36:57.269904
# On fastq pair number 8200000 at 2017-03-11 15:37:11.780661
# On fastq pair number 8700000 at 2017-03-11 15:37:18.491823
# On fastq pair number 8300000 at 2017-03-11 15:37:25.476027
# On fastq pair number 8300000 at 2017-03-11 15:37:36.673804
# On fastq pair number 8800000 at 2017-03-11 15:37:43.767418
# On fastq pair number 8400000 at 2017-03-11 15:37:51.224158
# On fastq pair number 8400000 at 2017-03-11 15:38:03.764859
# On fastq pair number 8900000 at 2017-03-11 15:38:13.180590
# On fastq pair number 8500000 at 2017-03-11 15:38:30.972538
# On fastq pair number 8500000 at 2017-03-11 15:38:44.652129
# On fastq pair number 9000000 at 2017-03-11 15:38:49.832867
# On fastq pair number 8600000 at 2017-03-11 15:39:09.188491
# On fastq pair number 8600000 at 2017-03-11 15:39:15.609513
# On fastq pair number 9100000 at 2017-03-11 15:39:19.983498
# On fastq pair number 8700000 at 2017-03-11 15:39:34.368707
# On fastq pair number 8700000 at 2017-03-11 15:39:36.832286
# On fastq pair number 9200000 at 2017-03-11 15:39:42.388365
# On fastq pair number 8800000 at 2017-03-11 15:39:58.895697
# On fastq pair number 8800000 at 2017-03-11 15:40:01.418906
# On fastq pair number 9300000 at 2017-03-11 15:40:05.183147
# On fastq pair number 8900000 at 2017-03-11 15:40:29.334303
# On fastq pair number 8900000 at 2017-03-11 15:40:32.012293
# On fastq pair number 9400000 at 2017-03-11 15:40:34.576849
# On fastq pair number 9000000 at 2017-03-11 15:40:52.217022
# On fastq pair number 9000000 at 2017-03-11 15:40:54.506699
# On fastq pair number 9500000 at 2017-03-11 15:40:56.564370
# On fastq pair number 9100000 at 2017-03-11 15:41:13.778969
# On fastq pair number 9100000 at 2017-03-11 15:41:16.793932
# On fastq pair number 9600000 at 2017-03-11 15:41:18.008819
# On fastq pair number 9200000 at 2017-03-11 15:41:35.994419
# On fastq pair number 9200000 at 2017-03-11 15:41:38.730810
# On fastq pair number 9700000 at 2017-03-11 15:41:39.520561
# On fastq pair number 9300000 at 2017-03-11 15:42:01.745862
# On fastq pair number 9300000 at 2017-03-11 15:42:04.544502
# On fastq pair number 9800000 at 2017-03-11 15:42:04.656220
# On fastq pair number 9400000 at 2017-03-11 15:42:23.162441
# On fastq pair number 9900000 at 2017-03-11 15:42:25.415154
# On fastq pair number 9400000 at 2017-03-11 15:42:25.648533
# On fastq pair number 9500000 at 2017-03-11 15:42:44.245508
# On fastq pair number 10000000 at 2017-03-11 15:42:46.331458
# On fastq pair number 9500000 at 2017-03-11 15:42:46.875738
# On fastq pair number 9600000 at 2017-03-11 15:43:06.331488
# On fastq pair number 10100000 at 2017-03-11 15:43:07.896592
# On fastq pair number 9600000 at 2017-03-11 15:43:09.302906
# On fastq pair number 9700000 at 2017-03-11 15:43:35.720900
# On fastq pair number 10200000 at 2017-03-11 15:43:35.751517
# On fastq pair number 9700000 at 2017-03-11 15:43:37.005541
# On fastq pair number 10300000 at 2017-03-11 15:43:58.867932
# On fastq pair number 9800000 at 2017-03-11 15:43:58.897262
# On fastq pair number 9800000 at 2017-03-11 15:43:59.906711
# On fastq pair number 10400000 at 2017-03-11 15:44:20.494048
# On fastq pair number 9900000 at 2017-03-11 15:44:21.050337
# On fastq pair number 9900000 at 2017-03-11 15:44:22.168358
# On fastq pair number 10500000 at 2017-03-11 15:44:43.380353
# On fastq pair number 10000000 at 2017-03-11 15:44:45.734750
# On fastq pair number 10000000 at 2017-03-11 15:44:47.422906
# On fastq pair number 10600000 at 2017-03-11 15:45:12.868398
# On fastq pair number 10100000 at 2017-03-11 15:45:14.251039
# On fastq pair number 10100000 at 2017-03-11 15:45:15.542612
# On fastq pair number 10700000 at 2017-03-11 15:45:36.292239
# On fastq pair number 10200000 at 2017-03-11 15:45:37.513695
# On fastq pair number 10200000 at 2017-03-11 15:45:38.658144
# On fastq pair number 10800000 at 2017-03-11 15:46:02.752269
# On fastq pair number 10300000 at 2017-03-11 15:46:04.105091
# On fastq pair number 10300000 at 2017-03-11 15:46:05.670950
# On fastq pair number 10900000 at 2017-03-11 15:46:28.809911
# On fastq pair number 10400000 at 2017-03-11 15:46:29.491229
# On fastq pair number 10400000 at 2017-03-11 15:46:30.753164
# On fastq pair number 11000000 at 2017-03-11 15:46:50.924675
# On fastq pair number 10500000 at 2017-03-11 15:46:51.429822
# On fastq pair number 10500000 at 2017-03-11 15:46:52.651749
# On fastq pair number 11100000 at 2017-03-11 15:47:16.745865
# On fastq pair number 10600000 at 2017-03-11 15:47:17.275243
# On fastq pair number 10600000 at 2017-03-11 15:47:18.295871
# A549-CV4-d21-2_S4_L002_001_trimmed53_len_filtered elapsed time: 0:44:49
# Starting A549-CV4-d28-2_S6_L001_001_trimmed53_len_filtered at 2017-03-11 15:47:19.764095
# On fastq pair number 10700000 at 2017-03-11 15:47:38.560861
# On fastq pair number 10700000 at 2017-03-11 15:47:39.460002
# On fastq pair number 100000 at 2017-03-11 15:47:41.778181
# On fastq pair number 10800000 at 2017-03-11 15:48:04.615912
# On fastq pair number 10800000 at 2017-03-11 15:48:05.682080
# On fastq pair number 200000 at 2017-03-11 15:48:08.470696
# On fastq pair number 10900000 at 2017-03-11 15:48:27.002245
# On fastq pair number 10900000 at 2017-03-11 15:48:28.178559
# On fastq pair number 300000 at 2017-03-11 15:48:30.840585
# On fastq pair number 11000000 at 2017-03-11 15:48:47.360753
# On fastq pair number 11000000 at 2017-03-11 15:48:48.835422
# On fastq pair number 400000 at 2017-03-11 15:48:51.442570
# On fastq pair number 11100000 at 2017-03-11 15:49:14.745806
# On fastq pair number 11100000 at 2017-03-11 15:49:16.690606
# On fastq pair number 500000 at 2017-03-11 15:49:19.771192
# On fastq pair number 11200000 at 2017-03-11 15:49:37.960451
# On fastq pair number 11200000 at 2017-03-11 15:49:39.303638
# On fastq pair number 600000 at 2017-03-11 15:49:42.175608
# On fastq pair number 11300000 at 2017-03-11 15:50:02.801940
# On fastq pair number 11300000 at 2017-03-11 15:50:04.098518
# On fastq pair number 700000 at 2017-03-11 15:50:06.663955
# On fastq pair number 11400000 at 2017-03-11 15:50:31.448496
# On fastq pair number 800000 at 2017-03-11 15:50:34.784374
# On fastq pair number 11400000 at 2017-03-11 15:50:36.596731
# On fastq pair number 11500000 at 2017-03-11 15:50:55.025667
# On fastq pair number 900000 at 2017-03-11 15:50:59.218264
# On fastq pair number 11500000 at 2017-03-11 15:51:16.544700
# On fastq pair number 11600000 at 2017-03-11 15:51:18.404462
# On fastq pair number 1000000 at 2017-03-11 15:51:22.981943
# On fastq pair number 11700000 at 2017-03-11 15:51:40.624569
# On fastq pair number 1100000 at 2017-03-11 15:51:45.630828
# On fastq pair number 11600000 at 2017-03-11 15:51:45.812788
# On fastq pair number 11800000 at 2017-03-11 15:52:12.261781
# On fastq pair number 1200000 at 2017-03-11 15:52:18.582344
# On fastq pair number 11700000 at 2017-03-11 15:52:20.128686
# On fastq pair number 11900000 at 2017-03-11 15:52:40.170821
# On fastq pair number 1300000 at 2017-03-11 15:52:44.331488
# On fastq pair number 11800000 at 2017-03-11 15:52:45.165194
# On fastq pair number 12000000 at 2017-03-11 15:53:03.737541
# On fastq pair number 1400000 at 2017-03-11 15:53:09.085985
# On fastq pair number 11900000 at 2017-03-11 15:53:09.570148
# On fastq pair number 12100000 at 2017-03-11 15:53:28.787690
# On fastq pair number 1500000 at 2017-03-11 15:53:34.119539
# On fastq pair number 12000000 at 2017-03-11 15:53:34.677842
# On fastq pair number 12200000 at 2017-03-11 15:53:51.995284
# On fastq pair number 1600000 at 2017-03-11 15:53:56.190932
# On fastq pair number 12100000 at 2017-03-11 15:53:56.686728
# On fastq pair number 12300000 at 2017-03-11 15:54:19.125831
# On fastq pair number 1700000 at 2017-03-11 15:54:23.501046
# On fastq pair number 12200000 at 2017-03-11 15:54:24.249030
# On fastq pair number 12400000 at 2017-03-11 15:54:41.945565
# On fastq pair number 1800000 at 2017-03-11 15:54:46.695981
# On fastq pair number 12300000 at 2017-03-11 15:54:46.907963
# On fastq pair number 12500000 at 2017-03-11 15:55:04.723022
# On fastq pair number 12400000 at 2017-03-11 15:55:09.574341
# On fastq pair number 1900000 at 2017-03-11 15:55:09.926677
# On fastq pair number 12600000 at 2017-03-11 15:55:32.583166
# On fastq pair number 2000000 at 2017-03-11 15:55:37.692189
# On fastq pair number 12500000 at 2017-03-11 15:55:38.313272
# On fastq pair number 12700000 at 2017-03-11 15:55:58.165140
# On fastq pair number 2100000 at 2017-03-11 15:56:03.694518
# On fastq pair number 12600000 at 2017-03-11 15:56:04.612638
# On fastq pair number 12800000 at 2017-03-11 15:56:23.688163
# On fastq pair number 2200000 at 2017-03-11 15:56:28.231920
# On fastq pair number 12700000 at 2017-03-11 15:56:28.951340
# On fastq pair number 12900000 at 2017-03-11 15:56:53.592623
# On fastq pair number 2300000 at 2017-03-11 15:56:59.833585
# On fastq pair number 12800000 at 2017-03-11 15:57:00.522211
# On fastq pair number 13000000 at 2017-03-11 15:57:24.629311
# On fastq pair number 2400000 at 2017-03-11 15:57:28.786096
# On fastq pair number 12900000 at 2017-03-11 15:57:29.687196
# On fastq pair number 13100000 at 2017-03-11 15:57:48.761350
# On fastq pair number 2500000 at 2017-03-11 15:57:52.514360
# On fastq pair number 13000000 at 2017-03-11 15:57:53.345541
# On fastq pair number 13200000 at 2017-03-11 15:58:13.192149
# On fastq pair number 2600000 at 2017-03-11 15:58:16.765656
# On fastq pair number 13100000 at 2017-03-11 15:58:17.062144
# On fastq pair number 13300000 at 2017-03-11 15:58:37.528125
# On fastq pair number 13200000 at 2017-03-11 15:58:41.860599
# On fastq pair number 2700000 at 2017-03-11 15:58:41.919646
# On fastq pair number 13400000 at 2017-03-11 15:59:05.572095
# On fastq pair number 2800000 at 2017-03-11 15:59:11.222963
# On fastq pair number 13300000 at 2017-03-11 15:59:11.232305
# A549-CV4-d28-1_S5_L001_001_trimmed53_len_filtered elapsed time: 0:56:12
# Starting A549-CV4-d28-2_S6_L002_001_trimmed53_len_filtered at 2017-03-11 15:59:12.458681
# A549-CV4-d28-1_S5_L002_001_trimmed53_len_filtered elapsed time: 0:55:11
# On fastq pair number 2900000 at 2017-03-11 15:59:31.622233
# On fastq pair number 100000 at 2017-03-11 15:59:32.530679
# On fastq pair number 3000000 at 2017-03-11 15:59:47.474212
# On fastq pair number 200000 at 2017-03-11 15:59:48.108877
# On fastq pair number 3100000 at 2017-03-11 16:00:03.654107
# On fastq pair number 300000 at 2017-03-11 16:00:03.823286
# On fastq pair number 400000 at 2017-03-11 16:00:19.809147
# On fastq pair number 3200000 at 2017-03-11 16:00:20.127370
# On fastq pair number 500000 at 2017-03-11 16:00:37.598143
# On fastq pair number 3300000 at 2017-03-11 16:00:38.086024
# On fastq pair number 600000 at 2017-03-11 16:00:53.515318
# On fastq pair number 3400000 at 2017-03-11 16:00:54.406884
# On fastq pair number 700000 at 2017-03-11 16:01:08.466536
# On fastq pair number 3500000 at 2017-03-11 16:01:09.624101
# On fastq pair number 800000 at 2017-03-11 16:01:23.176666
# On fastq pair number 3600000 at 2017-03-11 16:01:24.595542
# On fastq pair number 900000 at 2017-03-11 16:01:38.067946
# On fastq pair number 3700000 at 2017-03-11 16:01:39.515446
# On fastq pair number 1000000 at 2017-03-11 16:01:53.718330
# On fastq pair number 3800000 at 2017-03-11 16:01:55.572172
# On fastq pair number 1100000 at 2017-03-11 16:02:09.905665
# On fastq pair number 3900000 at 2017-03-11 16:02:12.800533
# On fastq pair number 1200000 at 2017-03-11 16:02:28.550106
# On fastq pair number 4000000 at 2017-03-11 16:02:30.067630
# On fastq pair number 1300000 at 2017-03-11 16:02:43.036818
# On fastq pair number 4100000 at 2017-03-11 16:02:44.553443
# On fastq pair number 1400000 at 2017-03-11 16:02:58.634637
# On fastq pair number 4200000 at 2017-03-11 16:03:00.076554
# On fastq pair number 1500000 at 2017-03-11 16:03:14.969623
# On fastq pair number 4300000 at 2017-03-11 16:03:16.376418
# On fastq pair number 1600000 at 2017-03-11 16:03:32.612801
# On fastq pair number 4400000 at 2017-03-11 16:03:33.844535
# On fastq pair number 1700000 at 2017-03-11 16:03:46.605521
# On fastq pair number 4500000 at 2017-03-11 16:03:48.521191
# On fastq pair number 1800000 at 2017-03-11 16:04:03.133484
# On fastq pair number 4600000 at 2017-03-11 16:04:04.601213
# On fastq pair number 1900000 at 2017-03-11 16:04:18.431008
# On fastq pair number 4700000 at 2017-03-11 16:04:19.433549
# On fastq pair number 2000000 at 2017-03-11 16:04:33.538391
# On fastq pair number 4800000 at 2017-03-11 16:04:34.427279
# On fastq pair number 2100000 at 2017-03-11 16:04:50.641520
# On fastq pair number 4900000 at 2017-03-11 16:04:51.369275
# On fastq pair number 2200000 at 2017-03-11 16:05:06.433467
# On fastq pair number 5000000 at 2017-03-11 16:05:06.796276
# On fastq pair number 2300000 at 2017-03-11 16:05:24.131143
# On fastq pair number 5100000 at 2017-03-11 16:05:24.819093
# On fastq pair number 2400000 at 2017-03-11 16:05:40.648348
# On fastq pair number 5200000 at 2017-03-11 16:05:41.884515
# On fastq pair number 2500000 at 2017-03-11 16:06:03.612655
# On fastq pair number 5300000 at 2017-03-11 16:06:04.263919
# On fastq pair number 2600000 at 2017-03-11 16:06:18.729504
# On fastq pair number 5400000 at 2017-03-11 16:06:19.357542
# On fastq pair number 2700000 at 2017-03-11 16:06:43.360490
# On fastq pair number 5500000 at 2017-03-11 16:06:43.944522
# On fastq pair number 2800000 at 2017-03-11 16:07:03.705664
# On fastq pair number 5600000 at 2017-03-11 16:07:04.182095
# On fastq pair number 2900000 at 2017-03-11 16:07:26.397601
# On fastq pair number 5700000 at 2017-03-11 16:07:26.666525
# On fastq pair number 5800000 at 2017-03-11 16:07:42.009482
# On fastq pair number 3000000 at 2017-03-11 16:07:42.152077
# On fastq pair number 5900000 at 2017-03-11 16:08:02.641347
# On fastq pair number 3100000 at 2017-03-11 16:08:02.981714
# On fastq pair number 6000000 at 2017-03-11 16:08:23.357987
# On fastq pair number 3200000 at 2017-03-11 16:08:23.639681
# On fastq pair number 6100000 at 2017-03-11 16:08:43.387626
# On fastq pair number 3300000 at 2017-03-11 16:08:43.897768
# On fastq pair number 6200000 at 2017-03-11 16:09:03.349161
# On fastq pair number 3400000 at 2017-03-11 16:09:03.656588
# On fastq pair number 6300000 at 2017-03-11 16:09:18.552578
# On fastq pair number 3500000 at 2017-03-11 16:09:19.064519
# On fastq pair number 6400000 at 2017-03-11 16:09:36.150854
# On fastq pair number 3600000 at 2017-03-11 16:09:36.796484
# On fastq pair number 6500000 at 2017-03-11 16:09:54.269847
# On fastq pair number 3700000 at 2017-03-11 16:09:55.059428
# On fastq pair number 6600000 at 2017-03-11 16:10:13.617336
# On fastq pair number 3800000 at 2017-03-11 16:10:14.533339
# On fastq pair number 6700000 at 2017-03-11 16:10:28.289458
# On fastq pair number 3900000 at 2017-03-11 16:10:29.190922
# On fastq pair number 6800000 at 2017-03-11 16:10:43.305921
# On fastq pair number 4000000 at 2017-03-11 16:10:44.145845
# On fastq pair number 6900000 at 2017-03-11 16:11:02.016547
# On fastq pair number 4100000 at 2017-03-11 16:11:02.622065
# On fastq pair number 7000000 at 2017-03-11 16:11:20.516842
# On fastq pair number 4200000 at 2017-03-11 16:11:20.892606
# On fastq pair number 7100000 at 2017-03-11 16:11:36.934415
# On fastq pair number 4300000 at 2017-03-11 16:11:37.227852
# On fastq pair number 7200000 at 2017-03-11 16:11:51.721043
# On fastq pair number 4400000 at 2017-03-11 16:11:51.930572
# On fastq pair number 7300000 at 2017-03-11 16:12:06.477381
# On fastq pair number 4500000 at 2017-03-11 16:12:06.506290
# On fastq pair number 4600000 at 2017-03-11 16:12:21.234014
# On fastq pair number 7400000 at 2017-03-11 16:12:21.504247
# On fastq pair number 4700000 at 2017-03-11 16:12:43.732024
# On fastq pair number 7500000 at 2017-03-11 16:12:43.943398
# On fastq pair number 4800000 at 2017-03-11 16:13:06.029274
# On fastq pair number 7600000 at 2017-03-11 16:13:06.343926
# On fastq pair number 4900000 at 2017-03-11 16:13:26.008632
# On fastq pair number 7700000 at 2017-03-11 16:13:26.300187
# On fastq pair number 5000000 at 2017-03-11 16:13:42.059316
# On fastq pair number 7800000 at 2017-03-11 16:13:42.233930
# On fastq pair number 7900000 at 2017-03-11 16:14:01.618934
# On fastq pair number 5100000 at 2017-03-11 16:14:01.719122
# On fastq pair number 8000000 at 2017-03-11 16:14:19.897811
# On fastq pair number 5200000 at 2017-03-11 16:14:20.298776
# On fastq pair number 8100000 at 2017-03-11 16:14:33.620044
# On fastq pair number 5300000 at 2017-03-11 16:14:34.253613
# On fastq pair number 8200000 at 2017-03-11 16:14:49.618574
# On fastq pair number 5400000 at 2017-03-11 16:14:50.348037
# On fastq pair number 8300000 at 2017-03-11 16:15:07.896695
# On fastq pair number 5500000 at 2017-03-11 16:15:08.691069
# On fastq pair number 5600000 at 2017-03-11 16:15:26.849614
# On fastq pair number 8400000 at 2017-03-11 16:15:31.595894
# On fastq pair number 5700000 at 2017-03-11 16:15:44.067733
# On fastq pair number 8500000 at 2017-03-11 16:15:57.952664
# On fastq pair number 5800000 at 2017-03-11 16:15:59.535443
# On fastq pair number 5900000 at 2017-03-11 16:16:13.954538
# On fastq pair number 8600000 at 2017-03-11 16:16:15.463822
# On fastq pair number 6000000 at 2017-03-11 16:16:28.279590
# On fastq pair number 8700000 at 2017-03-11 16:16:39.234996
# On fastq pair number 6100000 at 2017-03-11 16:16:48.109154
# On fastq pair number 8800000 at 2017-03-11 16:17:00.369165
# On fastq pair number 6200000 at 2017-03-11 16:17:01.867852
# On fastq pair number 6300000 at 2017-03-11 16:17:17.135109
# On fastq pair number 8900000 at 2017-03-11 16:17:22.332829
# On fastq pair number 6400000 at 2017-03-11 16:17:32.492718
# On fastq pair number 9000000 at 2017-03-11 16:17:38.032759
# On fastq pair number 6500000 at 2017-03-11 16:17:48.068870
# On fastq pair number 9100000 at 2017-03-11 16:17:58.631782
# On fastq pair number 6600000 at 2017-03-11 16:18:03.433224
# On fastq pair number 9200000 at 2017-03-11 16:18:20.734709
# On fastq pair number 6700000 at 2017-03-11 16:18:22.413288
# On fastq pair number 9300000 at 2017-03-11 16:18:37.066750
# On fastq pair number 6800000 at 2017-03-11 16:18:37.208075
# On fastq pair number 6900000 at 2017-03-11 16:18:51.951113
# On fastq pair number 9400000 at 2017-03-11 16:18:52.355803
# On fastq pair number 7000000 at 2017-03-11 16:19:06.934325
# On fastq pair number 9500000 at 2017-03-11 16:19:07.793607
# On fastq pair number 7100000 at 2017-03-11 16:19:22.209683
# On fastq pair number 9600000 at 2017-03-11 16:19:25.515491
# On fastq pair number 7200000 at 2017-03-11 16:19:38.311388
# On fastq pair number 9700000 at 2017-03-11 16:19:43.215433
# On fastq pair number 7300000 at 2017-03-11 16:19:55.100972
# On fastq pair number 9800000 at 2017-03-11 16:19:58.837738
# On fastq pair number 7400000 at 2017-03-11 16:20:11.341447
# On fastq pair number 9900000 at 2017-03-11 16:20:16.643216
# On fastq pair number 7500000 at 2017-03-11 16:20:26.733298
# On fastq pair number 10000000 at 2017-03-11 16:20:34.942876
# On fastq pair number 7600000 at 2017-03-11 16:20:42.056803
# On fastq pair number 10100000 at 2017-03-11 16:20:50.682383
# On fastq pair number 7700000 at 2017-03-11 16:20:59.451754
# On fastq pair number 10200000 at 2017-03-11 16:21:09.383860
# On fastq pair number 7800000 at 2017-03-11 16:21:20.481060
# On fastq pair number 10300000 at 2017-03-11 16:21:28.648524
# On fastq pair number 7900000 at 2017-03-11 16:21:36.386061
# On fastq pair number 10400000 at 2017-03-11 16:21:44.849544
# On fastq pair number 8000000 at 2017-03-11 16:21:53.510105
# On fastq pair number 10500000 at 2017-03-11 16:22:04.236972
# On fastq pair number 8100000 at 2017-03-11 16:22:10.760463
# On fastq pair number 10600000 at 2017-03-11 16:22:19.626680
# On fastq pair number 8200000 at 2017-03-11 16:22:26.404423
# On fastq pair number 10700000 at 2017-03-11 16:22:35.809012
# On fastq pair number 8300000 at 2017-03-11 16:22:43.198339
# On fastq pair number 10800000 at 2017-03-11 16:22:53.251335
# On fastq pair number 8400000 at 2017-03-11 16:23:01.902047
# On fastq pair number 10900000 at 2017-03-11 16:23:13.048166
# On fastq pair number 8500000 at 2017-03-11 16:23:20.739038
# On fastq pair number 11000000 at 2017-03-11 16:23:28.111357
# On fastq pair number 8600000 at 2017-03-11 16:23:34.682530
# On fastq pair number 11100000 at 2017-03-11 16:23:42.485742
# On fastq pair number 8700000 at 2017-03-11 16:23:49.385120
# On fastq pair number 11200000 at 2017-03-11 16:23:56.602097
# On fastq pair number 8800000 at 2017-03-11 16:24:03.085726
# On fastq pair number 11300000 at 2017-03-11 16:24:10.596576
# On fastq pair number 8900000 at 2017-03-11 16:24:19.473669
# On fastq pair number 11400000 at 2017-03-11 16:24:30.993560
# On fastq pair number 9000000 at 2017-03-11 16:24:37.379178
# On fastq pair number 11500000 at 2017-03-11 16:24:44.920716
# On fastq pair number 9100000 at 2017-03-11 16:24:51.202178
# On fastq pair number 11600000 at 2017-03-11 16:24:58.689249
# On fastq pair number 9200000 at 2017-03-11 16:25:07.349437
# On fastq pair number 11700000 at 2017-03-11 16:25:12.011828
# On fastq pair number 9300000 at 2017-03-11 16:25:20.933980
# On fastq pair number 11800000 at 2017-03-11 16:25:25.226075
# On fastq pair number 9400000 at 2017-03-11 16:25:34.240773
# On fastq pair number 11900000 at 2017-03-11 16:25:38.679134
# On fastq pair number 9500000 at 2017-03-11 16:25:47.727658
# On fastq pair number 12000000 at 2017-03-11 16:25:51.854605
# On fastq pair number 9600000 at 2017-03-11 16:26:01.157871
# On fastq pair number 12100000 at 2017-03-11 16:26:05.322584
# On fastq pair number 9700000 at 2017-03-11 16:26:17.109719
# On fastq pair number 12200000 at 2017-03-11 16:26:22.220768
# On fastq pair number 9800000 at 2017-03-11 16:26:32.077032
# On fastq pair number 12300000 at 2017-03-11 16:26:36.462743
# On fastq pair number 9900000 at 2017-03-11 16:26:45.866813
# On fastq pair number 12400000 at 2017-03-11 16:26:49.898390
# On fastq pair number 10000000 at 2017-03-11 16:26:59.391586
# On fastq pair number 12500000 at 2017-03-11 16:27:04.569422
# On fastq pair number 10100000 at 2017-03-11 16:27:17.898497
# On fastq pair number 12600000 at 2017-03-11 16:27:23.259114
# On fastq pair number 10200000 at 2017-03-11 16:27:36.625208
# On fastq pair number 12700000 at 2017-03-11 16:27:40.412794
# On fastq pair number 10300000 at 2017-03-11 16:27:50.743565
# On fastq pair number 12800000 at 2017-03-11 16:27:54.736768
# On fastq pair number 10400000 at 2017-03-11 16:28:05.634362
# On fastq pair number 12900000 at 2017-03-11 16:28:08.949453
# On fastq pair number 10500000 at 2017-03-11 16:28:19.250881
# On fastq pair number 13000000 at 2017-03-11 16:28:25.284089
# On fastq pair number 10600000 at 2017-03-11 16:28:35.439450
# On fastq pair number 13100000 at 2017-03-11 16:28:42.606274
# On fastq pair number 10700000 at 2017-03-11 16:28:52.695589
# On fastq pair number 10800000 at 2017-03-11 16:29:06.896939
# On fastq pair number 13200000 at 2017-03-11 16:29:08.050819
# On fastq pair number 10900000 at 2017-03-11 16:29:21.620598
# On fastq pair number 13300000 at 2017-03-11 16:29:28.612051
# On fastq pair number 11000000 at 2017-03-11 16:29:36.898351
# On fastq pair number 13400000 at 2017-03-11 16:29:45.829385
# On fastq pair number 11100000 at 2017-03-11 16:29:51.251353
# On fastq pair number 13500000 at 2017-03-11 16:30:04.303207
# On fastq pair number 11200000 at 2017-03-11 16:30:09.906834
# On fastq pair number 13600000 at 2017-03-11 16:30:18.353460
# On fastq pair number 11300000 at 2017-03-11 16:30:23.838659
# On fastq pair number 13700000 at 2017-03-11 16:30:32.805322
# On fastq pair number 11400000 at 2017-03-11 16:30:38.824485
# On fastq pair number 13800000 at 2017-03-11 16:30:47.744269
# On fastq pair number 11500000 at 2017-03-11 16:30:54.661634
# On fastq pair number 13900000 at 2017-03-11 16:31:03.069525
# On fastq pair number 11600000 at 2017-03-11 16:31:11.870564
# On fastq pair number 14000000 at 2017-03-11 16:31:21.483004
# On fastq pair number 11700000 at 2017-03-11 16:31:27.982840
# On fastq pair number 14100000 at 2017-03-11 16:31:36.232171
# On fastq pair number 11800000 at 2017-03-11 16:31:42.265275
# On fastq pair number 14200000 at 2017-03-11 16:31:52.161437
# On fastq pair number 11900000 at 2017-03-11 16:31:58.326466
# On fastq pair number 14300000 at 2017-03-11 16:32:08.157239
# On fastq pair number 12000000 at 2017-03-11 16:32:16.272955
# On fastq pair number 14400000 at 2017-03-11 16:32:29.623638
# On fastq pair number 12100000 at 2017-03-11 16:32:34.864343
# On fastq pair number 14500000 at 2017-03-11 16:32:44.436972
# On fastq pair number 12200000 at 2017-03-11 16:32:50.685616
# On fastq pair number 14600000 at 2017-03-11 16:33:01.600295
# On fastq pair number 12300000 at 2017-03-11 16:33:06.505591
# On fastq pair number 14700000 at 2017-03-11 16:33:19.845268
# On fastq pair number 12400000 at 2017-03-11 16:33:24.337662
# On fastq pair number 14800000 at 2017-03-11 16:33:38.904825
# On fastq pair number 12500000 at 2017-03-11 16:33:43.409222
# On fastq pair number 14900000 at 2017-03-11 16:33:55.460997
# On fastq pair number 12600000 at 2017-03-11 16:33:59.744759
# On fastq pair number 15000000 at 2017-03-11 16:34:11.934939
# On fastq pair number 12700000 at 2017-03-11 16:34:15.858544
# On fastq pair number 15100000 at 2017-03-11 16:34:27.721245
# On fastq pair number 12800000 at 2017-03-11 16:34:32.455905
# On fastq pair number 15200000 at 2017-03-11 16:34:44.010938
# On fastq pair number 12900000 at 2017-03-11 16:34:48.822733
# On fastq pair number 15300000 at 2017-03-11 16:34:59.673130
# On fastq pair number 13000000 at 2017-03-11 16:35:02.639532
# On fastq pair number 15400000 at 2017-03-11 16:35:13.062444
# A549-CV4-d28-2_S6_L001_001_trimmed53_len_filtered elapsed time: 0:47:55
# On fastq pair number 13100000 at 2017-03-11 16:35:15.932983
# On fastq pair number 13200000 at 2017-03-11 16:35:28.841910
# On fastq pair number 13300000 at 2017-03-11 16:35:41.851099
# On fastq pair number 13400000 at 2017-03-11 16:35:54.830238
# On fastq pair number 13500000 at 2017-03-11 16:36:09.714472
# On fastq pair number 13600000 at 2017-03-11 16:36:24.774056
# On fastq pair number 13700000 at 2017-03-11 16:36:38.391863
# On fastq pair number 13800000 at 2017-03-11 16:36:52.069573
# On fastq pair number 13900000 at 2017-03-11 16:37:07.128342
# On fastq pair number 14000000 at 2017-03-11 16:37:22.003203
# On fastq pair number 14100000 at 2017-03-11 16:37:36.168615
# On fastq pair number 14200000 at 2017-03-11 16:37:50.725645
# On fastq pair number 14300000 at 2017-03-11 16:38:04.364496
# On fastq pair number 14400000 at 2017-03-11 16:38:17.719140
# On fastq pair number 14500000 at 2017-03-11 16:38:33.261369
# On fastq pair number 14600000 at 2017-03-11 16:38:47.975320
# On fastq pair number 14700000 at 2017-03-11 16:39:01.455274
# On fastq pair number 14800000 at 2017-03-11 16:39:16.551017
# On fastq pair number 14900000 at 2017-03-11 16:39:31.411683
# On fastq pair number 15000000 at 2017-03-11 16:39:46.126836
# On fastq pair number 15100000 at 2017-03-11 16:40:00.233078
# On fastq pair number 15200000 at 2017-03-11 16:40:13.919357
# On fastq pair number 15300000 at 2017-03-11 16:40:28.753991
# On fastq pair number 15400000 at 2017-03-11 16:40:42.625732
# A549-CV4-d28-2_S6_L002_001_trimmed53_len_filtered elapsed time: 0:41:41
# parallel processing elapsed time: 2:29:15

# %%
print(ns_parallel.concatenate_parallel_results(g_parallel_results))
# Out:
# A549-CV4-d21-1_S3_L001_001_trimmed53_len_filtered: finished
# A549-CV4-d21-1_S3_L002_001_trimmed53_len_filtered: finished
# A549-CV4-d21-2_S4_L001_001_trimmed53_len_filtered: finished
# A549-CV4-d21-2_S4_L002_001_trimmed53_len_filtered: finished
# A549-CV4-d28-1_S5_L001_001_trimmed53_len_filtered: finished
# A549-CV4-d28-1_S5_L002_001_trimmed53_len_filtered: finished
# A549-CV4-d28-2_S6_L001_001_trimmed53_len_filtered: finished
# A549-CV4-d28-2_S6_L002_001_trimmed53_len_filtered: finished
